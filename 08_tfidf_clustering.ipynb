# %%
import random
import pandas as pd
from sklearn import feature_extraction
from sklearn.cluster import KMeans
from gensim.models.phrases import Phrases, ENGLISH_CONNECTOR_WORDS
import os

# %%
#Load the corpus
genre_name = "'American poetry'"

in_filepath = f"df_cleaned/{genre_name}/"
out_filepath = f'df_cleaned/{genre_name}/'
os.makedirs(f'{out_filepath}/{genre_name}', exist_ok=True)

delimiter = "line"

filename = f"{delimiter}_merged_df.csv"

# %%
df = pd.read_csv(in_filepath+filename, index_col = 0)
df
# Out:
#      Poem Title                                               line
# 0             I  in the acadian land on the shores of the basin...
# 1             I  lay in the fruitful valley  vast meadows stret...
# 2             I  giving the village its name and pasture to flo...
# 3             I  dikes that the hands of the farmers had raised...
# 4             I  shut out the turbulent tides but at stated sea...
# ...         ...                                                ...
# 1181         V.  only along the shore of the mournful and misty...
# 1182         V.  wandered back to their native land to die in i...
# 1183         V.  in the fishermans cot the wheel and the loom a...
# 1184         V.  maidens still wear their norman caps and their...
# 1185         V.  speaks and in accents disconsolate answers the...
#
# [1186 rows x 2 columns]

# %%
#Use association measures to find multi-word expressions in Gensim
phrase_model = Phrases([str(doc).split() for doc in df.loc[:,delimiter].values], 
                        min_count = 2, 
                        threshold = 0.7, 
                        connector_words = ENGLISH_CONNECTOR_WORDS, scoring = "npmi"
                        )

print(phrase_model.export_phrases().keys())
print("ABOVE: Learned phrases")
# Out:
# dict_keys(['basin_of_minas', 'matrons_and_maidens', 'within_doors', 'angelus_sounded', 'olden_time', 'father_felician', 'basil_the_blacksmith', 'nest_of_the_swallow', 'no_longer', 'acadian_peasants', 'lowing_of_cattle', 'flickering_light', 'old_mans', 'art_thou', 'seat_by_the_fireside', 'thou_hast', 'forebodings_of_ill', 'gaspereaus_mouth', 'port_royal', 'been_taken', 'made_answer', 'round_about', 'rené_leblanc', 'papers_and_inkhorn', 'old_french', 'french_fort', 'yet_am', 'i_know', 'better_than', 'statue_of_justice', 'laws_of_the_land', 'scales_of_the_balance', 'necklace_of_pearls', 'fain_would', 'tankard_of_ale', 'meanwhile_apart', 'silence_reigned', 'neighboring_hamlets', 'michael_the_fiddler', 'steps_of_the_altar', 'madly_rushed', 'our_homes', 'ascended_the_steps', 'gazing_upon', 'o_father', 'father_forgive', 'let_us', 'thus_did', 'risen_and_set', 'mournful_procession', 'household_goods', 'once_more', 'good_cheer', 'suddenly_paused', 'lifeless_head', 'faces_of_friends', 'leaving_behind', 'gabriel_lajeunesse', 'o_yes', 'yes_we', 'daughter_thy', 'feeling_of_wonder', 'blew_a_blast', 'glided_along', 'hunters_and_trappers', 'reverend_man', 'arose_and_continued', 'gust_of_wind', 'column_of_smoke', 'flowers_of_the_garden', 'garden_gate', 'numberless_herds', 'town_of_adayes', 'will_follow', 'ozark_mountains', 'beware_of_the_fever', 'fuller_of_fragrance', 'how_often', 'guides_and_companions', 'indian_guides', 'returning_home', 'black_robe', 'robe_chief', 'bloodred_ear', 'michigan_forests', 'faint_streaks', 'sister_of_mercy', 'silver_stream', 'forest_primeval', 'where_theirs'])
# ABOVE: Learned phrases

# %%
#Replace phrases in the df
df.loc[:,delimiter] = [" ".join(phrase_model[str(sentence).split()]) for sentence in df.loc[:,delimiter]]

# %%
#First find the most frequent words
features = feature_extraction.text.CountVectorizer(input='content', 
                                                encoding='utf-8', 
                                                decode_error='ignore', 
                                                lowercase=True, 
                                                tokenizer = None,
                                                ngram_range=(1, 1), 
                                                analyzer='word', 
                                                max_features=500,   #Choose number of future stopwords
                                                )

# %%
#Sklearn first fits then transforms
features.fit(df.loc[:,delimiter].values)
#The most frequent words can be found in the dictionary of vocabulary items
stopwords = list(features.vocabulary_.keys())
print(stopwords)
print("ABOVE: Frequent words to exclude")
# Out:
# ['in', 'the', 'acadian', 'land', 'on', 'shores', 'of', 'lay', 'vast', 'meadows', 'stretched', 'to', 'village', 'its', 'name', 'and', 'flocks', 'without', 'that', 'hands', 'farmers', 'had', 'with', 'labor', 'out', 'tides', 'but', 'at', 'opened', 'sea', 'will', 'oer', 'there', 'were', 'fields', 'afar', 'away', 'rose', 'forests', 'old', 'aloft', 'mountains', 'their', 'tents', 'from', 'looked', 'happy', 'descended', 'midst', 'farms', 'built', 'oak', 'such', 'as', 'summer', 'when', 'lighted', 'street', 'sat', 'snowwhite', 'green', 'golden', 'for', 'whose', 'mingled', 'sound', 'maidens', 'down', 'came', 'priest', 'children', 'paused', 'hand', 'he', 'extended', 'them', 'among', 'up', 'then', 'home', 'sun', 'sank', 'his', 'rest', 'twilight', 'anon', 'softly', 'over', 'roofs', 'columns', 'smoke', 'like', 'hundred', 'peace', 'love', 'god', 'man', 'they', 'fear', 'locks', 'nor', 'windows', 'dwellings', 'day', 'hearts', 'was', 'poor', 'lived', 'nearer', 'him', 'household', 'evangeline', 'child', 'form', 'an', 'is', 'white', 'snow', 'brown', 'fair', 'she', 'behold', 'maiden', 'her', 'eyes', 'by', 'yet', 'how', 'gleamed', 'beneath', 'shade', 'sweet', 'breath', 'ah', 'while', 'bell', 'sounds', 'air', 'long', 'passed', 'brought', 'since', 'face', 'after', 'it', 'seemed', 'music', 'house', 'farmer', 'stood', 'side', 'grew', 'door', 'around', 'through', 'meadow', 'or', 'farther', 'well', 'near', 'horses', 'north', 'barns', 'wains', 'folds', 'voice', 'each', 'one', 'far', 'under', 'odorous', 'too', 'meek', 'ever', 'above', 'thus', 'world', 'grandpré', 'many', 'youth', 'knelt', 'church', 'upon', 'who', 'might', 'darkness', 'waited', 'hear', 'footsteps', 'not', 'which', 'heart', 'whispered', 'words', 'all', 'young', 'gabriel', 'only', 'welcome', 'men', 'time', 'has', 'been', 'people', 'together', 'father_felician', 'swiftly', 'basil_the_blacksmith', 'take', 'place', 'round', 'oft', 'light', 'every', 'within', 'ceased', 'ashes', 'laughed', 'said', 'into', 'winter', 'swift', 'brings', 'shore', 'found', 'years', 'no_longer', 'morning', 'now', 'sunshine', 'called', 'would', 'bring', 'filling', 'full', 'faces', 'season', 'returned', 'birds', 'wild', 'trees', 'forest', 'angel', 'cold', 'be', 'autumn', 'followed', 'beautiful', 'filled', 'landscape', 'if', 'restless', 'ocean', 'moment', 'voices', 'great', 'yellow', 'bright', 'departed', 'descending', 'back', 'evening', 'sky', 'herds', 'ground', 'other', 'where', 'behind', 'slept', 'night', 'silence', 'late', 'moon', 'odor', 'wooden', 'unto', 'loud', 'heard', 'echoed', 'silent', 'burning', 'city', 'own', 'shadow', 'vanished', 'song', 'sang', 'fathers', 'before', 'close', 'are', 'so', 'suddenly', 'lifted', 'sounded', 'basil', 'my', 'friend', 'thy', 'thee', 'pipe', 'never', 'much', 'art_thou', 'friendly', 'smile', 'answered', 'others', 'see', 'embers', 'slowly', 'days', 'ships', 'us', 'what', 'may', 'morrow', 'alas', 'evil', 'these', 'our', 'cattle', 'blacksmith', 'head', 'forgotten', 'already', 'have', 'arms', 'left', 'we', 'than', 'no', 'sorrow', 'this', 'hearth', 'round_about', 'here', 'shall', 'window', 'father', 'died', 'lips', 'notary', 'entered', 'hung', 'high', 'look', 'more', 'times', 'told', 'water', 'unseen', 'right', 'some', 'those', 'things', 'done', 'just', 'story', 'me', 'tale', 'even', 'course', 'fell', 'met', 'heaven', 'spirit', 'lo', 'walls', 'ended', 'fain_would', 'thoughts', 'margin', 'silver', 'bridegroom', 'soon', 'made', 'rise', 'hour', 'guests', 'good', 'evangelines', 'moved', 'lamp', 'moonlight', 'till', 'tremulous', 'feet', 'floor', 'little', 'lover', 'sadness', 'soul', 'gazed', 'saw', 'forth', 'cloud', 'follow', 'wandered', 'soft', 'shadows', 'life', 'country', 'path', 'seen', 'streets', 'feasted', 'common', 'gave', 'spread', 'leaves', 'wind', 'women', 'graves', 'spake', 'you', 'your', 'lands', 'hope', 'prayer', 'deep', 'alone', 'another', 'still', 'o_father', 'let_us', 'repeated', 'broad', 'fallen', 'urged', 'weary', 'emotion', 'dead', 'length', 'fire', 'once_more', 'ran', 'claspe ...
# ABOVE: Frequent words to exclude

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorization
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df[delimiter])

# %%
# Clustering
k = 10  # You can experiment with the number of clusters
kmeans = KMeans(n_clusters=k)
df['cluster'] = kmeans.fit_predict(X)

# Check cluster assignments
print(df[[delimiter, 'cluster']])
# Out:
#                                                    line  cluster
# 0     in the acadian land on the shores of the basin...        8
# 1     lay in the fruitful valley vast meadows stretc...        8
# 2     giving the village its name and pasture to flo...        8
# 3     dikes that the hands of the farmers had raised...        8
# 4     shut out the turbulent tides but at stated sea...        8
# ...                                                 ...      ...
# 1181  only along the shore of the mournful and misty...        8
# 1182  wandered back to their native land to die in i...        8
# 1183  in the fishermans cot the wheel and the loom a...        8
# 1184  maidens still wear their norman caps and their...        8
# 1185  speaks and in accents disconsolate answers the...        8
#
# [1186 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# Assuming poem_df is your DataFrame containing poem stanzas and cluster assignments
# Replace 'poem_df' with the actual name of your DataFrame if it's different

# Sample a portion of the data (e.g., 10%)
# sampled_df = df.sample(frac=0.05, random_state=42)  # Adjust the fraction as needed
# print(len(sampled_df))

# Vectorization
# vectorizer = TfidfVectorizer()
# X_sampled = vectorizer.fit_transform(df[delimiter])

# Reduce the dimensionality of the feature space for visualization
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X.toarray())

# Create a DataFrame for visualization
viz_df = pd.DataFrame(X_reduced, columns=['PC1', 'PC2'])
viz_df['cluster'] = df['cluster']

# Plot the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PC1', y='PC2', hue='cluster', data=viz_df, palette='viridis', legend='full')
plt.title('Clustering of Sampled Poem Stanzas')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Calculate silhouette score
silhouette_avg = silhouette_score(X, df['cluster'])  # X is your data

print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.004164350673759556
